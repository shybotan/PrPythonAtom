# %%
class Entry:
    def __init__(self, key, value):
        #TODO store key and value as attributes
        self.key=key
        self.value=value
        self.next=[]
        #ОП. КАЖЕТСЯ ЭТО КОНСТРУКТОР
    def get_key(self):
        #TODO return key
        return self.key
    def get_value(self):
        #TODO return value
        return self.value
    def __eq__(self, other):
        #TODO реализовать функцию сравнения
        #Пояснения: self - текущий объект entry, other - какой-то другой объект
        #Какое условие на равенство объектов в ассоциативном массиве?
        #Если объекты равны, то метод должен возвращать True, иначе False
        if(self.key==other.key):
            return True
        else:
            return False 
class HashMap:
    class Entry:
        def __init__(self, key, value):
            #TODO store key and value as attributes
            self.key=key
            self.value=value
            self.next=[]
            #ОП. КАЖЕТСЯ ЭТО КОНСТРУКТОР
        def get_key(self):
            #TODO return key
            return self.key
        def get_value(self):
            #TODO return value
            return self.value
        def __eq__(self, other):
            #TODO реализовать функцию сравнения
            #Пояснения: self - текущий объект entry, other - какой-то другой объект
            #Какое условие на равенство объектов в ассоциативном массиве?
            #Если объекты равны, то метод должен возвращать True, иначе False
            if(self.key==other.key):
                return True
            else:
                return False  
    
    def __init__(self, bucket_num = 64):
        #TODO Создать массив для бакетов
        self.a=[]
        for i in range(0,bucket_num):
            self.a.append(Entry(None,None))
        #ОП. КОСТРУКТОР
    def get(self, key, default_value=None):
        #TODO метод get, возвращающий значение, если оно присутствует, иначе default_value
        k = self._get_index(self._get_hash(key))
        if self.a[k] == Entry(None,None):
            return default_value
        if self.a[k].key == key:
            return self.a[k].value
        else:
            for i in range(0, len(self.a[k].next)):
                if self.a[k].next[i].key == key:
                    return self.a[k].next[i].value
        return default_value
                
    def put(self, key, value):
        #TODO метод put, кладет значение по ключу, в случае, если ключ уже присутствует он его заменяет
        k = self._get_index(self._get_hash(key))
        if (self.a[k].key == None):
            self.a[k] = Entry(key,value)
            return
        else:
            if self.a[k].get_key() == key:
                self.a[k].value = value
            else:
                for i in range(0, len(self.a[k].next)):
                    if self.a[k].next[i].key == key:
                        self.a[k].next[i].value = value
                self.a[k].next.append(Entry(key, value))

    def __len__(self):
        #TODO Возвращает количество Entry в массиве
        p=0
        for i in range(0,len(self.a)):
            if(self.a[i]!=Entry(None,None)):
                p=p+1+len(self.a[i].next)
        return p

    def _get_hash(self, key):
        #TODO Вернуть хеш от ключа, по которому он кладется в бакет
        #return ((key+11)%len(self.a))
        return hash(key)

    def _get_index(self, hash_value):
        #TODO По значению хеша вернуть индекс элемента в массиве
        #return hash(hash_value*3)%len(self.a)
        return hash(hash_value*3+3)%len(self.a)
    #1 взаимнопростое с 64
    def values(self):
        #TODO Задание со звездочкой!
        #Должен возвращать генератор или итератор ключей (на самом деле итератор, но не принципиально, через генераторы проще ИМХО)
        i=-1
        while i<len(self.a):
            i=i+1
            j=-1
            if(i==len(self.a)): 
                raise StopIteration
            n=self.a[i]
            if n!=Entry(None,None):
                if j==-1:
                    yield n.get_value()
                    while j< len(n.next):
                        j=j+1
                        if(j==len(n.next)):
                            i=i+1
                            continue
                        if n.next[j].get_value()!=None:
                            yield n.next[j].get_value()
    def keys(self):
        #TODO Задание со звездочкой!
        #Должен возвращать генератор или итератор ключей (на самом деле итератор, но не принципиально, через генераторы проще ИМХО)
        i=-1
        while i<len(self.a):
            i=i+1
            j=-1
            if(i==len(self.a)): 
                raise StopIteration
            n=self.a[i]
            if n!=Entry(None,None):
                if j==-1:
                    yield n.get_value()
                    while j< len(n.next):
                        j=j+1
                        if(j==len(n.next)):
                            i=i+1
                            continue
                        if n.next[j].get_key()!=None:
                            yield n.next[j].get_key()
    def items(self):
        #TODO Задание со звездочкой!
        #Должен возвращать генератор или итератор пар ключ и значение (tuples)
        #(на самом деле итератор, но не принципиально, через генераторы проще ИМХО)
        i=-1
        while i<len(self.a):
            i=i+1
            j=-1
            if(i==len(self.a)): 
                raise StopIteration
            n=self.a[i]
            if n!=Entry(None,None):
                if j==-1:
                    p=n.get_key(),n.get_value()
                    yield tuple(p)
                    while j< len(n.next):
                        j=j+1
                        if(j==len(n.next)):
                            i=i+1
                            continue
                        if n.next[j].get_value()!=None:
                            p=n.next[j].get_key(),n.next[j].get_value()
                            yield tuple(p)
    def __str__(self):
        #TODO Метод, вызываемый при вызове print, пофантазируйте, что можно написать
        res = ""
        for i in range(0, len(self.a)):
            if(self.a[i]!=Entry(None,None)):
                res = res + " { key:"
                res = res + str(self.a[i].get_key()) 
                res = res + "; value: "
                res = res + str(self.a[i].get_value())
                res = res + " }"+"\n"
                for j in range(0, len(self.a[i].next)):
                    res = res + " { key:"
                    res = res + str(self.a[i].next[j].get_key()) 
                    res = res + "; value: "
                    res = res + str(self.a[i].next[j].get_value())
                    res = res + " }"+"\n"
        res = res + "\n"+" Hashmap"
        return res

def test_hashmap_04():

    entries = [(5, 7), ("entries", 56), ("value", 54.), (1000, "t"), (HashMap(10), ()), ({"s":"v"}, {"v":"s"})]

    for k, v in entries:

        entry = HashMap.Entry(k, v)

        assert entry.get_key() == k

        assert entry.get_value() == v
    print("Test 4 part 01 passed")

        

    for i in range(len(entries)):

        entry_one = HashMap.Entry(entries[i][0], entries[i][1])

        for _ in range(10):

            j = random.randint(0, len(entries)-1)

            p = random.randint(0, len(entries)-1)

            entry_two = HashMap.Entry(entries[j][0], entries[p][1])

            if j == i:

                assert entry_one == entry_two

            else:

                assert entry_one != entry_two

    print("Test 4 part 02 passed")

    

def test_hashmap_05():

    hashmap = HashMap(10)

    assert sum(isinstance(v, list) for k, v in hashmap.__dict__.items()) == 1

    print("Test 5 part 01 passed")

    

    inner_list_name = [k for k, v in hashmap.__dict__.items() if isinstance(v, list)][0]

    for i in range(10):

        assert len(HashMap(i).__dict__[inner_list_name]) == i

    print("Test 5 part 02 passed")

    

def test_hashmap_06():

    hashmap = HashMap(10)

    entries = [(5, 7), ("entries", 56), ("value", 54.), (1000, "t"),(HashMap(10),()) ]

    for k, v in entries:

        hashmap.put(k, v)
    for k, v in entries:
        assert hashmap.get(k) == v

    print("Test 6 part 01 passed")

    

    for _ in range(100):

        i = random.randint(0, len(entries)-1)

        j = random.randint(0, len(entries)-1)

        hashmap.put(i, j)
        assert hashmap.get(i) == j
    assert hashmap.get("nexit", "default") =="default"
    

    print("Test 6 part 02 passed")
test_hashmap_05()
test_hashmap_04()
test_hashmap_06()
# Out:
# Test 5 part 01 passed
# Test 5 part 02 passed
# Test 4 part 01 passed
# Test 4 part 02 passed
# Test 6 part 01 passed
# Test 6 part 02 passed

# %%
class HashSet(HashMap):
    def __init__(self, bucket_num=64):
        self.a=[]
        for _ in range(0, bucket_num):
            self.a.append(Entry(None,None))
   
    def get(self, key, default_value=None):
        #TODO достаточно переопределить данный метод
        k = self._get_index(self._get_hash(key))
        if self.a[k] == Entry(None,None):
            return default_value
        if self.a[k].key == key:
            return key
        else:
            for i in range(0, len(self.a[k].next)):
                if self.a[k].next[i].key == key:
                    return key
        return default_value
    def put(self, key):
        #TODO метод put, нужно переопределить данный метод
        k = self._get_index(self._get_hash(key))
        if (self.a[k].key == None):
            self.a[k] = Entry(key,"BUSY")
            return 
        else:
            if self.a[k].get_key() != key:
                for i in range(0, len(self.a[k].next)):
                    if self.a[k].next[i].key != key:
                        continue
                self.a[k].next.append(Entry(key,"BUSY"))
    def __len__(self):
        #TODO Возвращает количество Entry в массиве
        p=0
        for i in range(0,len(self.a)):
            if(self.a[i]!=Entry(None,None)):
                p=p+1+len(self.a[i].next)
        return p
        
    def values(self):
        #TODO Задание со звездочкой!
        #Если делали, то нужно бы переопределить
        #Должен возвращать генератор или итератор значений (на самом деле итератор, но не принципиально, через генераторы проще ИМХО)
        i=-1
        while i<len(self.a):
            i=i+1
            j=-1
            if(i==len(self.a)): 
                raise StopIteration
            n=self.a[i]
            if n!=Entry(None,None):
                if j==-1:
                    yield n.get_key()
                    while j< len(n.next):
                        j=j+1
                        if(j==len(n.next)):
                            i=i+1
                            continue
                        if n.next[j].get_value()!=None:
                            yield n.next[j].get_key()
    def __str__(self):
        res = ""
        for i in range(0, len(self.a)):
            if(self.a[i]!=Entry(None,None)):
                res = res + " { key:"
                res = res + str(self.a[i].get_key()) 
                res = res + "; value: "
                res = res + "BUSY"
                res = res + " }"+"\n"
                for j in range(0, len(self.a[i].next)):
                    res = res + " { key:"
                    res = res + str(self.a[i].next[j].get_key()) 
                    res = res + "; value: "
                    res = res + "BUSY"
                    res = res + " }"+"\n"
        res = res + "\n"+" Hashmap"
        return res
